# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
from string import punctuation
nltk.download('stopwords')
from nltk.tokenize import word_tokenize 
nltk.download('punkt')
from nltk.tokenize import RegexpTokenizer
from itertools import combinations
from itertools import groupby
from itertools import combinations
import itertools
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def cleantext(sentence):
  sentence = sentence.lower()
  tokenizer = RegexpTokenizer(r'\w+')
  tokens = tokenizer.tokenize(sentence)
  filtered_words = [w for w in tokens if not w in stopwords.words('english')]
  return " ".join(filtered_words)

# %%
def Uniquewords(s):
  s=cleantext(s)

  no_dupes = ([k for k, v in groupby(s.split())])
  return no_dupes

# %%
#Loading Data
amazondata = pd.read_json('http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz', lines=True)

# %%
df=pd.DataFrame(amazondata)

# %%
text=df.reviewText[0]
x=Uniquewords(text)

# %%
x
# Out:
# ['bought',
#  'first',
#  'hp12c',
#  '1984',
#  'served',
#  'faithfully',
#  '2002',
#  'lost',
#  'travelling',
#  'searched',
#  'another',
#  'one',
#  'replace',
#  'found',
#  'one',
#  'difficult',
#  'come',
#  'area',
#  'decided',
#  'buy',
#  'purchased',
#  'hp',
#  '49g',
#  'mistake',
#  'know',
#  'many',
#  'people',
#  'view',
#  'hp',
#  '49g',
#  'flagship',
#  'hp',
#  'line',
#  'disaster',
#  '49g',
#  'may',
#  'powerful',
#  'using',
#  'extremely',
#  'counterintuitive',
#  'manual',
#  'sketchy',
#  'best',
#  '12c',
#  'hand',
#  'need',
#  'way',
#  'makes',
#  'good',
#  'sense',
#  'looking',
#  'solid',
#  'reliable',
#  'calculator',
#  'hp12c',
#  'may',
#  'programmable',
#  'basic',
#  'statistics',
#  'well',
#  'many',
#  'business',
#  'applications',
#  'manual',
#  'makes',
#  'sense',
#  'running',
#  'short',
#  'order',
#  'ready',
#  'set',
#  '49g',
#  'aside',
#  'move',
#  'back',
#  'old',
#  'friend',
#  'even',
#  'replace',
# ...

# %%
#Import itertools package
from itertools import combinations

def comn(iter,r):
     combi = combinations(iter,r)
     for c in list(combi):
      print(c)

# %%
y=comn(x,2)
# Out:
# ('bought', 'first')
# ('bought', 'hp12c')
# ('bought', '1984')
# ('bought', 'served')
# ('bought', 'faithfully')
# ('bought', '2002')
# ('bought', 'lost')
# ('bought', 'travelling')
# ('bought', 'searched')
# ('bought', 'another')
# ('bought', 'one')
# ('bought', 'replace')
# ('bought', 'found')
# ('bought', 'one')
# ('bought', 'difficult')
# ('bought', 'come')
# ('bought', 'area')
# ('bought', 'decided')
# ('bought', 'buy')
# ('bought', 'purchased')
# ('bought', 'hp')
# ('bought', '49g')
# ('bought', 'mistake')
# ('bought', 'know')
# ('bought', 'many')
# ('bought', 'people')
# ('bought', 'view')
# ('bought', 'hp')
# ('bought', '49g')
# ('bought', 'flagship')
# ('bought', 'hp')
# ('bought', 'line')
# ('bought', 'disaster')
# ('bought', '49g')
# ('bought', 'may')
# ('bought', 'powerful')
# ('bought', 'using')
# ('bought', 'extremely')
# ('bought', 'counterintuitive')
# ('bought', 'manual')
# ('bought', 'sketchy')
# ('bought', 'best')
# ('bought', '12c')
# ('bought', 'hand')
# ...

# %%
type(y)

# %%
import gensim
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile

# %%
from gensim.models import Word2Vec
from gensim.test.utils import common_texts, get_tmpfile

# %%
model = gensim.models.Word2Vec(wordlist,  size=100, window=5, min_count=1, workers=4)
#model = gensim.models.Word2Vec(ftest, min_count=1)
print(model)
# Out:
# Word2Vec(vocab=71, size=100, alpha=0.025)

# %%
words = list(model.wv.vocab)
print(words)
# Out:
# ['bought', 'first', 'hp12c', '1984', 'served', 'faithfully', '2002', 'lost', 'travelling', 'searched', 'another', 'one', 'replace', 'found', 'difficult', 'come', 'area', 'decided', 'buy', 'purchased', 'hp', '49g', 'mistake', 'know', 'many', 'people', 'view', 'flagship', 'line', 'disaster', 'may', 'powerful', 'using', 'extremely', 'counterintuitive', 'manual', 'sketchy', 'best', '12c', 'hand', 'need', 'way', 'makes', 'good', 'sense', 'looking', 'solid', 'reliable', 'calculator', 'programmable', 'basic', 'statistics', 'well', 'business', 'applications', 'running', 'short', 'order', 'ready', 'set', 'aside', 'move', 'back', 'old', 'friend', 'even', 'batteries', 'decade', 'use', 'coming', 'home']

# %%
wordlist=[[word] for word in x]

# %%
wordlist
# Out:
# [['bought'],
#  ['first'],
#  ['hp12c'],
#  ['1984'],
#  ['served'],
#  ['faithfully'],
#  ['2002'],
#  ['lost'],
#  ['travelling'],
#  ['searched'],
#  ['another'],
#  ['one'],
#  ['replace'],
#  ['found'],
#  ['one'],
#  ['difficult'],
#  ['come'],
#  ['area'],
#  ['decided'],
#  ['buy'],
#  ['purchased'],
#  ['hp'],
#  ['49g'],
#  ['mistake'],
#  ['know'],
#  ['many'],
#  ['people'],
#  ['view'],
#  ['hp'],
#  ['49g'],
#  ['flagship'],
#  ['hp'],
#  ['line'],
#  ['disaster'],
#  ['49g'],
#  ['may'],
#  ['powerful'],
#  ['using'],
#  ['extremely'],
#  ['counterintuitive'],
#  ['manual'],
#  ['sketchy'],
#  ['best'],
#  ['12c'],
#  ['hand'],
#  ['need'],
#  ['way'],
#  ['makes'],
#  ['good'],
#  ['sense'],
#  ['looking'],
#  ['solid'],
#  ['reliable'],
#  ['calculator'],
#  ['hp12c'],
#  ['may'],
#  ['programmable'],
#  ['basic'],
#  ['statistics'],
#  ['well'],
#  ['many'],
#  ['business'],
#  ['applications'],
#  ['manual'],
#  ['makes'],
#  ['sense'],
#  ['running'],
# ...

# %%
for i in wordlist:
  for j in wordlist:
    if j>i:
      print('Similarity between ',i[0],' & ',j[0],' is: ',model.similarity(i[0],j[0]))
    else:
      continue
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# Similarity between  bought  &  first  is:  -0.069194764
# Similarity between  bought  &  hp12c  is:  0.23859951
# Similarity between  bought  &  served  is:  0.02900189
# Similarity between  bought  &  faithfully  is:  0.14563833
# Similarity between  bought  &  lost  is:  -0.23158312
# Similarity between  bought  &  travelling  is:  0.12769271
# Similarity between  bought  &  searched  is:  -0.052318394
# Similarity between  bought  &  one  is:  0.014695041
# ...
